# %% [markdown]
# **Dia 3 - estatística**

# %% [markdown]
# Os professores geralmente reclama de rouquidão.
# Os problemas nas cordas vocais são oriundos de diversos fatores de saúde física, mental e social.
#
# Clique duas vezes(ou pressione "Enter") para editar

# %% [markdown]
# - Qual a quantidade de turnos que trabalha atualmente?
#
# 1 a 3
#
# - Qual a quantidade de água consumida diariamente?
#
# - Você come maçã?
#
# - Tem gastrite?
#
# - Você é cantor profissional ou amador?
#
# - Existe barulho externos em seu ambiente de trabalho?
#
# - Existe barulho internos em seu ambiente de trabalho?
#
# - Solicitação de silêncio na turma?
#
# - Você toma café?
#
# - Você toma chá?
#
# - Você realiza exercícios de Fono?
#
# - Que tipos de exercícios você normalmente faz?
#   a) Nenhum
#   b) Antes da aula
#   c) Depois da aula
#   d) Antes e depoos da aula

# %%
# Passo 1 - Identificar as variáveis
# Que tipo de variável é cada uma na situação problema
# Excel - cadastrar algumas respotas.(professor, perguntas, respostas)

# %% [markdown]
# Variáveis:

# %% [markdown]
# # Dataset:
# ##Formatos
# - .xml
# - .json
# - .txt
# - .csv

# %%
# !pip install pandas

# %%
import pandas as pd

# %%
df = pd.read_csv('https://raw.githubusercontent.com/MatheusSales2773/Python_Developer/main/ciencia_de_dados/datasets/dados-experimento.csv',encoding='latin-1', sep=';')
df
# Out:
#   professor  qtde_turnos  qtde_agua maca tem_gastrite cantor barulho_externo  \
# 0      João            2       1000  sim          não    não             não
# 1    Rômulo            3       1000  não          sim    não             sim
# 2  Danielle            1       1500  sim          sim    não             não
#
#   barulho_interno silencio_turma toma_cafe toma_cha exercicio rouquidão  \
# 0             sim            sim       sim      não    nenhum       sim
# 1             sim            sim       não      não    depois       sim
# 2             sim            sim       sim      sim    nenhum       sim
#
#          nenhum
# 0         antes
# 1        depois
# 2  antes_depois

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   professor        3 non-null      object
#  1   qtde_turnos      3 non-null      int64
#  2   qtde_agua        3 non-null      int64
#  3   maca             3 non-null      object
#  4   tem_gastrite     3 non-null      object
#  5   cantor           3 non-null      object
#  6   barulho_externo  3 non-null      object
#  7   barulho_interno  3 non-null      object
#  8   silencio_turma   3 non-null      object
#  9   toma_cafe        3 non-null      object
#  10  toma_cha         3 non-null      object
#  11  exercicio        3 non-null      object
#  12  rouquidão        3 non-null      object
#  13  nenhum           3 non-null      object
# dtypes: int64(2), object(12)
# memory usage: 468.0+ bytes

# %%
df.describe()
# Out:
#        qtde_turnos    qtde_agua
# count          3.0     3.000000
# mean           2.0  1166.666667
# std            1.0   288.675135
# min            1.0  1000.000000
# 25%            1.5  1000.000000
# 50%            2.0  1000.000000
# 75%            2.5  1250.000000
# max            3.0  1500.000000

# %% [markdown]
# Cálculo para quantidade ideal de água que deve ser ingerida por dia:

# %%
peso = float(input(f"Coloque seu peso: ").replace(",","."))
ml = 35

quantidade_de_agua = ml * peso

print(f"Quantidade de água necessária para cosumo é: {quantidade_de_agua}ml")
# Out:
# Coloque seu peso: 90
# Quantidade de água necessária para cosumo é: 3150.0ml
